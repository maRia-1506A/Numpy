# %%
import numpy as np

# %%
np.array((1,2,3,4,5))
# Out:
# array([1, 2, 3, 4, 5])

# %%
a= np.array([1,2,3,4,5])
b= np.array([7,8,9,10,11])
c = np.array([[1, 2, 3], [4, 5, 6]])

# %%
print(f'{a}\n{b}\n{c}')
# Out:
# [1 2 3 4 5]
# [ 7  8  9 10 11]
# [[1 2 3]
#  [4 5 6]]

# %%
print(a[0]+b[0])
# Out:
# 8

# %%
print(f'2nd element of 2nd row: {c[1, 1]}')
# Out:
# 2nd element of 2nd row: 5

# %%
print(a[1:])
# Out:
# [2 3 4 5]

# %%
print(b[-3:-1])
# Out:
# [ 9 10]
